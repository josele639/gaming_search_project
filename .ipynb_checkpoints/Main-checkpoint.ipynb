# %% [markdown]
# # gaming_search_project
#
# ## TODO's
# You recently created a new company in the `GAMING industry`. The company will have the following scheme:
# - 20 Designers
# - 5 UI/UX Engineers
# - 10 Frontend Developers
# - 15 Data Engineers
# - 5 Backend Developers
# - 20 Account Managers
# - 1 Maintenance guy that loves basketball
# - 10 Executives
# - 1 CEO/President
#
# As a data engineer you have asked all the employees to show their preferences on where to place the new office.
# Your goal is to place the **new company offices** in the best place for the company to grow.
# You have to found a place that more or less covers all the following requirements.
# Note that **it's impossible to cover all requirements**, so you have to prioritize at your glance.
#
# - Designers like to go to design talks and share knowledge. There must be some nearby companies that also do design.
# - 30% of the company have at least 1 child.
# - Developers like to be near successful tech startups that have raised at least 1 Million dollars.
# - Executives like Starbucks A LOT. Ensure there's a starbucks not to far.
# - Account managers need to travel a lot
# - All people in the company have between 25 and 40 years, give them some place to go to party.
# - Nobody in the company likes to have companies with more than 10 years in a radius of 2 KM.
# - The CEO is Vegan
# ## Help
# - Geospatial range Queries in MongoDB with `pymongo`
# - GeoJSON Point `{ type: "Point", coordinates: [ 40, 5 ] }`
# - Create sphere2d index in python: `db.collection.createIndex( { <location field> : "2dsphere" } )`
# - Query `$near` operator: https://docs.mongodb.com/manual/reference/operator/query/near/#op._S_near
# ## How to deliver the project
# - You must justify your decision with tableau slides. Provide us the public tableau link inside a README.md
#   file at dir `module-2/project-mongodb-geospartial-queries`.
# - Provide `lat` and `long` for the new offices.
# ## Links & Resources
# - https://docs.mongodb.com/manual/geospatial-queries/
# - https://developers.google.com/maps/documentation/geocoding/intro
# - https://data.crunchbase.com/docs
# - https://developers.google.com/places/web-service/search
# - https://www.youtube.com/watch?v=PtV-ZnwCjT0

# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client.companies

# %%
companies = db.companies.find()

# %%
data_companies = pd.DataFrame(companies)

# %%
data_companies.shape
# Out:
# (18801, 42)

# %% [markdown]
# La manera en la que voy a estructurar este trabajo, siendo los criterios en base a las empresas anexas los más numerosos es
# basandome principalmente en las empresas que cumplan esos criterios, para despues, utilizar los demas criterios para elegir
# la mejor localizacion dentro del rango conseguido.

# %% [markdown]
# # 1. DataFrame con el mayor numero de empresas que esten juntas y cumplan los criterios.

# %%
acquisition = db.companies.find(
    {"$and":
     [
         {"offices.latitude": {"$exists": True}},
         {"founded_year": {"$gte": 2007}}, 
         {"total_money_raised":{"$regex":'M'}},
         {'deadpooled_year': { '$type': 10 }},
         {"$or": [
             {"category_code": "web"},
             {"category_code": "games_video"},
             {"category_code": "mobile"},
             {"category_code": "social"},
             {"category_code": "software"},
             {"category_code": "design"},
             {'category_code': 'games_video'},
             {'category_code': 'ecommerce'},
             {'category_code': 'hardware'}
         ]
         }
     ]
    })

# %%
df = pd.DataFrame(acquisition)

# %%
df.shape
# Out:
# (396, 42)

# %%
df.head()
# Out:
#                         _id          name     permalink  \
# 0  52cdef7c4bab8bd675297d9c       MeetMoi       meetmoi
# 1  52cdef7c4bab8bd675297da9        Mahalo        mahalo
# 2  52cdef7c4bab8bd675297dc2  AdaptiveBlue  adaptiveblue
# 3  52cdef7c4bab8bd675297dc0    Livestream    livestream
# 4  52cdef7c4bab8bd675297dc1       Ustream       ustream
#
#                                    crunchbase_url               homepage_url  \
# 0       http://www.crunchbase.com/company/meetmoi     http://www.meetmoi.com
# 1        http://www.crunchbase.com/company/mahalo          http://mahalo.com
# 2  http://www.crunchbase.com/company/adaptiveblue     http://www.getglue.com
# 3    http://www.crunchbase.com/company/livestream  http://www.livestream.com
# 4       http://www.crunchbase.com/company/ustream      http://www.ustream.tv
#
#                           blog_url                              blog_feed_url  \
# 0
# 1          http://blog.mahalo.com/               http://blog.mahalo.com/feed/
# 2     http://blog.adaptiveblue.com    http://blog.adaptiveblue.com/?feed=rss2
# 3  http://www.livestream.com/blog/  http://www.livestream.com/blog/?feed=rss2
# 4      http://www.ustream.com/blog           http://www.ustream.com/blog/feed
#
#   twitter_username category_code  number_of_employees  ...  investments  \
# 0          meetmoi        social                 15.0  ...           []
# 1     MahaloDotCom           web                 40.0  ...           []
# 2          GetGlue   games_video                 15.0  ...           []
# 3       livestream   games_video                120.0  ...           []
# 4          USTREAM   games_video                250.0  ...           []
#
#                                          acquisition  acquisitions  \
# 0                                               None            []
# 1                                               None            []
# 2                                               None            []
# 3  {'price_amount': None, 'price_currency_code': ...            []
# 4                                               None            []
#
#                                              offices  \
# 0  [{'description': None, 'address1': '', 'addres...
# 1  [{'description': '', 'address1': '3525 Eastham...
# 2  [{'description': '', 'address1': '131 Varick S...
# 3  [{'description': 'Livestream HQ', 'address1': ...
# 4  [{'description': 'San Francisco Office', 'addr...
#
#                                           milestones   ipo  \
# 0                                                 []  None
# 1                                                 []  None
# 2                                                 []  None
# 3                                                 []  None
# 4  [{'id': 6587, 'description': 'Ustream recogniz...  None
#
#                                         video_embeds  \
# 0  [{'embed_code': '<iframe src="http://player.vi...
# 1  [{'embed_code': '<embed src="http://blip.tv/pl...
# 2  [{'embed_code': '<object width="425" height="3...
# 3  [{'embed_code': '<embed src="http://blip.tv/pl...
# 4  [{'embed_code': '<object id="flashObj" width="...
#
#                                          screenshots  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'available_sizes': [[[150, 103], 'assets/ima...
#
#                                       external_links partners
# 0  [{'external_url': 'http://www.sociableblog.com...       []
# 1                                                 []       []
# 2  [{'external_url': 'http://web20show.com/2009/1...       []
# 3  [{'external_url': 'http://scobleizer.com/2007/...       []
# 4  [{'external_url': 'http://facebook.com/ustream...       []
#
# [5 rows x 42 columns]

# %%
df_con_dir = df

# %%
df_con_dir['latitud'] = df_con_dir.apply(lambda row: row['offices'][0]['latitude'], axis=1)
df_con_dir['longitud'] = df_con_dir.apply(lambda row: row['offices'][0]['longitude'], axis=1)
df_con_dir['city'] = df_con_dir.apply(lambda row: row['offices'][0]['city'], axis=1)
df_con_dir['country_code'] = df_con_dir.apply(lambda row: row['offices'][0]['country_code'], axis=1)

# %%
df_con_dir
# Out:
#                           _id               name          permalink  \
# 0    52cdef7c4bab8bd675297d9c            MeetMoi            meetmoi
# 1    52cdef7c4bab8bd675297da9             Mahalo             mahalo
# 2    52cdef7c4bab8bd675297dc2       AdaptiveBlue       adaptiveblue
# 3    52cdef7c4bab8bd675297dc0         Livestream         livestream
# 4    52cdef7c4bab8bd675297dc1            Ustream            ustream
# ..                        ...                ...                ...
# 391  52cdef7f4bab8bd67529c5a8         Antix Labs         antix-labs
# 392  52cdef7f4bab8bd67529c679  Bump Technologies  bump-technologies
# 393  52cdef7f4bab8bd67529c6b6         Tiny Speck         tiny-speck
# 394  52cdef7f4bab8bd67529c6d9           iGuiders           iguiders
# 395  52cdef7f4bab8bd67529c6e4             Getyoo             getyoo
#
#                                         crunchbase_url  \
# 0            http://www.crunchbase.com/company/meetmoi
# 1             http://www.crunchbase.com/company/mahalo
# 2       http://www.crunchbase.com/company/adaptiveblue
# 3         http://www.crunchbase.com/company/livestream
# 4            http://www.crunchbase.com/company/ustream
# ..                                                 ...
# 391       http://www.crunchbase.com/company/antix-labs
# 392  http://www.crunchbase.com/company/bump-technol...
# 393       http://www.crunchbase.com/company/tiny-speck
# 394         http://www.crunchbase.com/company/iguiders
# 395           http://www.crunchbase.com/company/getyoo
#
#                   homepage_url                         blog_url  \
# 0       http://www.meetmoi.com
# 1            http://mahalo.com          http://blog.mahalo.com/
# 2       http://www.getglue.com     http://blog.adaptiveblue.com
# 3    http://www.livestream.com  http://www.livestream.com/blog/
# 4        http://www.ustream.tv      http://www.ustream.com/blog
# ..                         ...                              ...
# 391       http://antixlabs.com
# 392               http://bu.mp               http://blog.bu.mp/
# 393       http://tinyspeck.com
# 394    http://www.iguiders.com
# 395      http://www.getyoo.com        http://getyoo.tumblr.com/
#
#                                  blog_feed_url twitter_username category_code  \
# 0                                                       meetmoi        social
# 1                 http://blog.mahalo.com/feed/     MahaloDotCom           web
# 2      http://blog.adaptiveblue.com/?feed=rss2          GetGlue   games_video
# 3    http://www.livestream.com/blog/?feed=rss2       livestream   games_video
# 4             http://www.ustream.com/blog/feed          USTREAM   games_video
# ..                                         ...              ...           ...
# 391                                                   Antix_Man   games_video
# 392                                                    bumptech        mobile
# 393                                                     slackhq   games_video
# 394                                                    iGuiders           web
# 395               http://getyoo.tumblr.com/rss           getyoo        mobile
#
#      number_of_employees  ...  \
# 0                   15.0  ...
# 1                   40.0  ...
# 2                   15.0  ...
# 3                  120.0  ...
# 4                  250.0  ...
# ..                   ...  ...
# 391                  NaN  ...
# 392                  NaN  ...
# 393                 45.0  ...
# 394                  5.0  ...
# 395                 10.0  ...
#
#                                             milestones   ipo  \
# 0                                                   []  None
# 1                                                   []  None
# 2                                                   []  None
# 3                                                   []  None
# 4    [{'id': 6587, 'description': 'Ustream recogniz...  None
# ..                                                 ...   ...
# 391  [{'id': 7121, 'description': 'Antix and Teleca...  None
# 392                                                 []  None
# 393                                                 []  None
# 394                                                 []  None
# 395                                                 []  None
#
#                                           video_embeds  \
# 0    [{'embed_code': '<iframe src="http://player.vi...
# 1    [{'embed_code': '<embed src="http://blip.tv/pl...
# 2    [{'embed_code': '<object width="425" height="3...
# 3    [{'embed_code': '<embed src="http://blip.tv/pl...
# 4    [{'embed_code': '<object id="flashObj" width="...
# ..                                                 ...
# 391  [{'embed_code': '<iframe width="560" height="3...
# 392                                                 []
# 393                                                 []
# 394  [{'embed_code': '<embed src="http://blip.tv/pl...
# 395  [{'embed_code': '<object width="448" height="2...
#
#                                            screenshots  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'available_sizes': [[[150, 103], 'assets/ima...
# ..                                                 ...
# 391  [{'available_sizes': [[[150, 115], 'assets/ima...
# 392  [{'available_sizes': [[[150, 148], 'assets/ima...
# 393  [{'available_sizes': [[[150, 73], 'assets/imag...
# 394  [{'available_sizes': [[[150, 90], 'assets/imag...
# 395  [{'available_sizes': [[[150, 93], 'assets/imag...
#
#                                         external_links partners    latitud  \
# 0    [{'external_url': 'http://www.sociableblog.com...       []  40.757929
# 1                                                   []       []  34.017606
# 2    [{'external_url': 'http://web20show.com/2009/1...       []  40.801358
# 3    [{'external_url': 'http://scobleizer.com/2007/...       []  40.726155
# 4    [{'external_url': 'http://facebook.com/ustream...       []  37.392936
# ..                                                 ...      ...        ...
# 391                                                 []       []        NaN
# 392                                                 []       []        NaN
# 393                                                 []       []  49.282455
# 394                                                 []       []        NaN
# 395  [{'external_url': 'http://www.youtube.com/watc...       []  50.839970
#
#        longitud           city country_code
# 0    -73.985506  New York City          USA
# 1   -118.487267    Culver City          USA
# 2    -74.337200            NYC          USA
# 3    -73.995625       New York          USA
# 4   -122.079480  San Francisco          USA
# ..          ...            ...          ...
# 391         NaN      Berkshire          GBR
# 392         NaN  Mountain View          USA
# 393 -123.109217      Vancouver          CAN
# 394         NaN      Beachwood          USA
# 395    4.346472       Brussels          BEL
#
# [396 rows x 46 columns]

# %%
df_con_dir['dir'] = df_con_dir[['longitud', 'latitud']].apply(list, axis=1)
df_con_dir['longitud'].isnull().sum()

df_con_dir = df_con_dir.dropna(subset=['longitud'])

# %%
lista_dir = df_con_dir.dir

# %%
df_con_dir['country_code'].value_counts()
# Out:
# USA    234
# GBR     14
# CAN     10
# FRA      9
# DEU      4
# ESP      4
# ISR      4
# NLD      4
# CHE      1
# IND      1
# AUS      1
# BEL      1
# DNK      1
# SWE      1
# IRL      1
# FIN      1
# AUT      1
# BRA      1
# ARG      1
# EST      1
# HUN      1
# Name: country_code, dtype: int64

# %%
def geopoint(x): 
        return {"type": "Point", "coordinates": x}

# %%
df_con_dir['dir'] = lista_dir.apply(geopoint)
# Out:
# C:\Users\traba\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_con_dir.shape
# Out:
# (296, 47)

# %%
df_con_dir.columns
# Out:
# Index(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url',
#        'blog_url', 'blog_feed_url', 'twitter_username', 'category_code',
#        'number_of_employees', 'founded_year', 'founded_month', 'founded_day',
#        'deadpooled_year', 'deadpooled_month', 'deadpooled_day',
#        'deadpooled_url', 'tag_list', 'alias_list', 'email_address',
#        'phone_number', 'description', 'created_at', 'updated_at', 'overview',
#        'image', 'products', 'relationships', 'competitions', 'providerships',
#        'total_money_raised', 'funding_rounds', 'investments', 'acquisition',
#        'acquisitions', 'offices', 'milestones', 'ipo', 'video_embeds',
#        'screenshots', 'external_links', 'partners', 'latitud', 'longitud',
#        'city', 'country_code', 'dir'],
#       dtype='object')

# %%
df_final=df_con_dir[['name','founded_year','homepage_url','category_code','description','total_money_raised','city','country_code', 'dir']]


df_final = df_final.rename(columns={'dir':'coordinates'})
df_final["coordinates"]
# Out:
# 0      {'type': 'Point', 'coordinates': [-73.985506, ...
# 1      {'type': 'Point', 'coordinates': [-118.487267,...
# 2      {'type': 'Point', 'coordinates': [-74.3372, 40...
# 3      {'type': 'Point', 'coordinates': [-73.995625, ...
# 4      {'type': 'Point', 'coordinates': [-122.07948, ...
#                              ...
# 384    {'type': 'Point', 'coordinates': [-0.1037742, ...
# 385    {'type': 'Point', 'coordinates': [-118.4660597...
# 390    {'type': 'Point', 'coordinates': [-73.2435522,...
# 393    {'type': 'Point', 'coordinates': [-123.109217,...
# 395    {'type': 'Point', 'coordinates': [4.3464721, 5...
# Name: coordinates, Length: 296, dtype: object

# %%
df_final.to_json("df_thefinal.json",orient="records", lines=True)

# %%
db = client.companies

# %%
df = db.cordenadas.find()
df = pd.DataFrame(df)
df
# Out:
#                           _id          name  founded_year  \
# 0    5d85cfe7ddf31cca9f5c0429       GoingOn          2008
# 1    5d85cfe7ddf31cca9f5c042a       Wakoopa          2007
# 2    5d85cfe7ddf31cca9f5c042b      Filtrbox          2007
# 3    5d85cfe7ddf31cca9f5c042c  Funny Or Die          2007
# 4    5d85cfe7ddf31cca9f5c042d      SodaHead          2007
# ..                        ...           ...           ...
# 291  5d85cfe7ddf31cca9f5c054c   Culture Jam          2008
# 292  5d85cfe7ddf31cca9f5c054d    Tiny Speck          2009
# 293  5d85cfe7ddf31cca9f5c054e     Testplant          2008
# 294  5d85cfe7ddf31cca9f5c054f       Teambox          2009
# 295  5d85cfe7ddf31cca9f5c0550        Getyoo          2009
#
#                     homepage_url category_code  \
# 0         http://www.goingon.com      software
# 1         http://www.wakoopa.com           web
# 2    http://www.jivesoftware.com           web
# 3          http://funnyordie.com   games_video
# 4            http://sodahead.com           web
# ..                           ...           ...
# 291     http://site.promojam.com           web
# 292         http://tinyspeck.com   games_video
# 293     http://www.testplant.com      software
# 294       http://www.teambox.com           web
# 295        http://www.getyoo.com        mobile
#
#                              description total_money_raised           city  \
# 0              Private Academic Networks              $8.5M  San Francisco
# 1    Social network for desktop software                $1M      Amsterdam
# 2    social media monitoring & analytics             $1.92M      Palo Alto
# 3                   comedy video website               $18M      San Mateo
# 4        Online Community and Discussion             $12.7M         Encino
# ..                                   ...                ...            ...
# 291  Innovative Social Media Technology               $1.7M    Los Angeles
# 292                                                  $17.2M      Vancouver
# 293                        GUI test tool             $2.56M         London
# 294       Collaboration and file sharing             $6.75M      Barcelona
# 295                 NFC Events Solutions             €1.13M       Brussels
#
#     country_code                                        coordinates
# 0            USA  {'type': 'Point', 'coordinates': [-122.392142,...
# 1            NLD  {'type': 'Point', 'coordinates': [4.8948623, 5...
# 2            USA  {'type': 'Point', 'coordinates': [-105.276843,...
# 3            USA  {'type': 'Point', 'coordinates': [-122.137444,...
# 4            USA  {'type': 'Point', 'coordinates': [-119.306607,...
# ..           ...                                                ...
# 291          USA  {'type': 'Point', 'coordinates': [-118.4660597...
# 292          CAN  {'type': 'Point', 'coordinates': [-123.109217,...
# 293          GBR  {'type': 'Point', 'coordinates': [-0.1037742, ...
# 294          ESP  {'type': 'Point', 'coordinates': [2.1920231, 4...
# 295          BEL  {'type': 'Point', 'coordinates': [4.3464721, 5...
#
# [296 rows x 10 columns]

# %%
df = df.drop(['_id'], axis=1)

# %%
def geonear(geopoint, maxdistance=1000):
    return db.cordenadas.find({
        "coordinates":{
            "$near":{
                "$geometry":geopoint,
                "$maxDistance":maxdistance
            }}})

# %%
# Aqui saco el numero de la lista que mas cumple el geonear.
lista = []
for i in range(296):
    ofis = df.iloc[i,]
    cuenta = geonear(ofis.coordinates, 3000).count()
    lista.append(cuenta)
    
maximo = lista.index(max(lista))
maximo
# Out:
# C:\Users\traba\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """
# 0

# %%
test = df.iloc[maximo, ]
cercanos = geonear(test.coordinates, 3000)
sf_point = test.coordinates["coordinates"]

# %%
sf_data = pd.DataFrame(cercanos)
sf_data
# Out:
#                          _id              name  founded_year  \
# 0   5d85cfe7ddf31cca9f5c0429           GoingOn          2008
# 1   5d85cfe7ddf31cca9f5c0431       Crunchyroll          2008
# 2   5d85cfe7ddf31cca9f5c050a             Skout          2007
# 3   5d85cfe7ddf31cca9f5c052f          Fotomoto          2008
# 4   5d85cfe7ddf31cca9f5c04f6              Meez          2009
# 5   5d85cfe7ddf31cca9f5c053b         ShopSavvy          2008
# 6   5d85cfe7ddf31cca9f5c044e            Disqus          2007
# 7   5d85cfe7ddf31cca9f5c04cf        Reframe It          2007
# 8   5d85cfe7ddf31cca9f5c04dd          DocVerse          2007
# 9   5d85cfe7ddf31cca9f5c04c6           Lolapps          2008
# 10  5d85cfe7ddf31cca9f5c04bc           Lolapps          2008
# 11  5d85cfe7ddf31cca9f5c042e              Yola          2007
# 12  5d85cfe7ddf31cca9f5c04be          Involver          2007
# 13  5d85cfe7ddf31cca9f5c0484  Serious Business          2008
# 14  5d85cfe7ddf31cca9f5c04aa           Huddler          2007
# 15  5d85cfe7ddf31cca9f5c04a9           Genbook          2007
# 16  5d85cfe7ddf31cca9f5c04c4              Lyft          2007
# 17  5d85cfe7ddf31cca9f5c04b9              Lyft          2007
# 18  5d85cfe7ddf31cca9f5c046e             Roost          2007
# 19  5d85cfe7ddf31cca9f5c044b            Gydget          2007
# 20  5d85cfe7ddf31cca9f5c04c3      InnerRewards          2008
# 21  5d85cfe7ddf31cca9f5c04d1      InnerRewards          2008
# 22  5d85cfe7ddf31cca9f5c0497         Transpera          2007
# 23  5d85cfe7ddf31cca9f5c0458           Lookery          2007
# 24  5d85cfe7ddf31cca9f5c04f0        5th Finger          2008
# 25  5d85cfe7ddf31cca9f5c0511            Heyzap          2009
# 26  5d85cfe7ddf31cca9f5c04b2            ngmoco          2008
# 27  5d85cfe7ddf31cca9f5c04d0            PicApp          2008
# 28  5d85cfe7ddf31cca9f5c0469         99designs          2008
# 29  5d85cfe7ddf31cca9f5c050c              KODA          2008
# 30  5d85cfe7ddf31cca9f5c0438           Dropbox          2007
# 31  5d85cfe7ddf31cca9f5c04e2       Clikthrough          2007
# 32  5d85cfe7ddf31cca9f5c0493             Zoosk          2007
# 33  5d85cfe7ddf31cca9f5c04ce         GoodGuide          2007
# 34  5d85cfe7ddf31cca9f5c04ba         GoodGuide          2007
# 35  5d85cfe7ddf31cca9f5c04eb           Coveroo          2008
# 36  5d85cfe7ddf31cca9f5c04ab            Minted          2007
# 37  5d85cfe7ddf31cca9f5c046a             Zynga          2007
# 38  5d85cfe7ddf31cca9f5c0529         Kidlandia          2008
# 39  5d85cfe7ddf31cca9f5c04a8         Posterous          2008
# 40  5d85cfe7ddf31cca9f5c0491          Stitcher          2008
# 41  5d85cfe7ddf31cca9f5c047d            GitHub          2008
# 42  5d85cfe7ddf31cca9f5c043d           Seesmic          2007
# 43  5d85cfe7ddf31cca9f5c0454          Outspark          2007
# 44  5d85cfe7ddf31cca9f5c045a       doubleTwist          2007
# 45  5d85cfe7ddf31cca9f5c044f        GameLayers          2007
# 46  5d85cfe7ddf31cca9f5c04a7       Open Places          2008
#
#                       homepage_url category_code  \
# 0           http://www.goingon.com      software
# 1       http://www.crunchyroll.com   games_video
# 2             http://www.skout.com        social
# 3          http://www.fotomoto.com     ecommerce
# 4                  http://meez.com      hardware
# 5             http://shopsavvy.com        mobile
# 6            http://www.disqus.com           web
# 7             http://reframeit.com           web
# 8          http://www.docverse.com           web
# 9           http://www.lolapps.com           web
# 10          http://www.lolapps.com           web
# 11             http://www.yola.com           web
# 12         http://www.involver.com      software
# 13  http://www.seriousbusiness.com   games_video
# 14          http://www.huddler.com           web
# 15          http://www.genbook.com           web
# 16                 http://lyft.com      software
# 17                 http://lyft.com      software
# 18            http://www.roost.com      software
# 19           http://www.gydget.com           web
# 20     http://www.InnerRewards.com     ecommerce
# 21     http://www.InnerRewards.com     ecommerce
# 22        http://www.transpera.com        mobile
# 23          http://www.lookery.com           web
# 24        http://www.5thFinger.com        mobile
# 25           http://www.heyzap.com   games_video
# 26           http://www.ngmoco.com   games_video
# 27           http://www.picapp.com           web
# 28            http://99designs.com        design
# 29                  http://koda.us           web
# 30          http://www.dropbox.com      software
# 31          http://clikthrough.com      software
# 32            http://www.zoosk.com        social
# 33            http://goodguide.com           web
# 34            http://goodguide.com           web
# 35          http://www.coveroo.com      hardware
# 36           http://www.minted.com     ecommerce
# 37            http://www.zynga.com   games_video
# 38   http://kidlandia.yolasite.com           web
# 39            http://posterous.com           web
# 40         http://www.stitcher.com        mobile
# 41               http://github.com      software
# 42              http://seesmic.com           web
# 43         http://www.outspark.com   games_video
# 44      http://www.doubletwist.com      software
# 45           http://gamelayers.com           web
# 46              http://openplac.es           web
#
#                                  description total_money_raised  \
# 0                  Private Academic Networks              $8.5M
# 1   Digital Entertainment and Media Platform              $4.8M
# 2          Mobile App for Meeting New People               $22M
# 3         Sell photos online on your website             $1.82M
# 4                      Avatar community site             $10.2M
# 5                                                        $11.5M
# 6         The Web's Community of Communities             $10.5M
# 7                                                        $3.18M
# 8                     Document collaboration              $1.3M
# 9                                                           $4M
# 10                                                          $4M
# 11                             Free Websites               $25M
# 12                 Social Marketing Platform             $11.3M
# 13            Social Game Development Studio                $4M
# 14                      We Know Communities.             $22.8M
# 15                                                        $2.2M
# 16                   Your friend with a car™             $82.5M
# 17                   Your friend with a car™             $82.5M
# 18                 Social Marketing Platform             $13.5M
# 19                    Marketing Widget Maker                $1M
# 20         Spa and Well-being social network                $1M
# 21         Spa and Well-being social network                $1M
# 22                  mobile video advertising             $19.5M
# 23                Social Network Advertising             $3.15M
# 24      Responsive Design Solutions Provider                $7M
# 25                 Social Discovery Platform             $7.97M
# 26                      Games for the iPhone             $44.8M
# 27                                                        $3.2M
# 28         Online graphic design marketplace               $35M
# 29     Social Recruiting and Job Search Site              $4.5M
# 30  Always have your stuff, wherever you are              $257M
# 31                        Interactive Videos                $2M
# 32                Behavioral Matchmaking(TM)             $61.6M
# 33                    Rating and review site             $14.2M
# 34                    Rating and review site             $14.2M
# 35                                                        $3.8M
# 36            marketplace for design and art             $52.7M
# 37            Network of gaming applications              $860M
# 38                                                       $3.23M
# 39                   Web Publishing Platform             $10.1M
# 40      It is a leading mobile audio company             $18.7M
# 41                             Social Coding              $100M
# 42              Social software applications               $16M
# 43                     Video game publishing             $23.3M
# 44          Music for the Internet of Things              $7.5M
# 45               Multiplayer Networked Games                $2M
# 46                                    Travel              $1.1M
#
#              city country_code  \
# 0   San Francisco          USA
# 1   San Francisco          USA
# 2   San Francisco          USA
# 3   San Francisco          USA
# 4   San Francisco          USA
# 5   San Francsico          USA
# 6   San Francisco          USA
# 7   San Francisco          USA
# 8   San Francisco          USA
# 9   San Francisco          USA
# 10  San Francisco          USA
# 11  San Francisco          USA
# 12  San Francisco          USA
# 13  San Francisco          USA
# 14  San Francisco          USA
# 15  San Francisco          USA
# 16  San Francisco          USA
# 17  San Francisco          USA
# 18  San Francisco          USA
# 19  San Francisco          USA
# 20  San Francisco          USA
# 21  San Francisco          USA
# 22  San Francisco          USA
# 23  San Francisco          USA
# 24  San Francisco          USA
# 25  San Francisco          USA
# 26  San Francisco          USA
# 27  San Francisco          USA
# 28  San Francisco          USA
# 29  San Francisco          USA
# 30  San Francisco          USA
# 31  San Francisco          USA
# 32  San Francisco          USA
# 33  San Francisco          USA
# 34  San Francisco          USA
# 35  San Francisco          USA
# 36  San Francisco          USA
# 37  San Francisco          USA
# 38  SAN FRANCISCO          USA
# 39  San Francisco          USA
# 40  San Francisco          USA
# 41  San Francisco          USA
# 42  San Francisco          USA
# 43  San Francisco          USA
# 44  San Francisco          USA
# 45  San Francisco          USA
# 46  San Francisco          USA
#
#                                           coordinates
# 0   {'type': 'Point', 'coordinates': [-122.392142,...
# 1   {'type': 'Point', 'coordinates': [-122.393229,...
# 2   {'type': 'Point', 'coordinates': [-122.3912492...
# 3   {'type': 'Point', 'coordinates': [-122.3948712...
# 4   {'type': 'Point', 'coordinates': [-122.397582,...
# 5   {'type': 'Point', 'coordinates': [-122.3966273...
# 6   {'type': 'Point', 'coordinates': [-122.397672,...
# 7   {'type': 'Point', 'coordinates': [-122.400591,...
# 8   {'type': 'Point', 'coordinates': [-122.397141,...
# 9   {'type': 'Point', 'coordinates': [-122.3999719...
# 10  {'type': 'Point', 'coordinates': [-122.3999719...
# 11  {'type': 'Point', 'coordinates': [-122.3954751...
# 12  {'type': 'Point', 'coordinates': [-122.401333,...
# 13  {'type': 'Point', 'coordinates': [-122.4013624...
# 14  {'type': 'Point', 'coordinates': [-122.4013624...
# 15  {'type': 'Point', 'coordinates': [-122.4007791...
# 16  {'type': 'Point', 'coordinates': [-122.4007846...
# 17  {'type': 'Point', 'coordinates': [-122.4007846...
# 18  {'type': 'Point', 'coordinates': [-122.4020276...
# 19  {'type': 'Point', 'coordinates': [-122.398398,...
# 20  {'type': 'Point', 'coordinates': [-122.404403,...
# 21  {'type': 'Point', 'coordinates': [-122.404403,...
# 22  {'type': 'Point', 'coordinates': [-122.405081,...
# 23  {'type': 'Point', 'coordinates': [-122.403865,...
# 24  {'type': 'Point', 'coordinates': [-122.4021988...
# 25  {'type': 'Point', 'coordinates': [-122.4041485...
# 26  {'type': 'Point', 'coordinates': [-122.4015807...
# 27  {'type': 'Point', 'coordinates': [-122.4031242...
# 28  {'type': 'Point', 'coordinates': [-122.4005983...
# 29  {'type': 'Point', 'coordinates': [-122.40971, ...
# 30  {'type': 'Point', 'coordinates': [-122.4084994...
# 31  {'type': 'Point', 'coordinates': [-122.4022856...
# 32  {'type': 'Point', 'coordinates': [-122.4099154...
# 33  {'type': 'Point', 'coordinates': [-122.4000032...
# 34  {'type': 'Point', 'coordinates': [-122.4000032...
# 35  {'type': 'Point', 'coordinates': [-122.407603,...
# 36  {'type': 'Point', 'coordinates': [-122.403175,...
# 37  {'type': 'Point', 'coordinates': [-122.404234,...
# 38  {'type': 'Point', 'coordinates': [-122.4043215...
# 39  {'type': 'Point', 'coordinates': [-122.419204,...
# 40  {'type': 'Point', 'coordinates': [-122.419204,...
# 41  {'type': 'Point', 'coordinates': [-122.419204,...
# 42  {'type': 'Point', 'coordinates': [-122.419204,...
# 43  {'type': 'Point', 'coordinates': [-122.419204,...
# 44  {'type': 'Point', 'coordinates': [-122.419204,...
# 45  {'type': 'Point', 'coordinates': [-122.402468,...
# 46  {'type': 'Point', 'coordinates': [-122.398379,...

# %%
sf_data['long'] = sf_data.apply(lambda row: row['coordinates']['coordinates'][0], axis=1)
sf_data['lat'] = sf_data.apply(lambda row: row['coordinates']['coordinates'][1], axis=1)

sf_data.drop(['_id','coordinates'], axis='columns', inplace=True)

sf_data
# Out:
#                 name  founded_year                    homepage_url  \
# 0            GoingOn          2008          http://www.goingon.com
# 1        Crunchyroll          2008      http://www.crunchyroll.com
# 2              Skout          2007            http://www.skout.com
# 3           Fotomoto          2008         http://www.fotomoto.com
# 4               Meez          2009                 http://meez.com
# 5          ShopSavvy          2008            http://shopsavvy.com
# 6             Disqus          2007           http://www.disqus.com
# 7         Reframe It          2007            http://reframeit.com
# 8           DocVerse          2007         http://www.docverse.com
# 9            Lolapps          2008          http://www.lolapps.com
# 10           Lolapps          2008          http://www.lolapps.com
# 11              Yola          2007             http://www.yola.com
# 12          Involver          2007         http://www.involver.com
# 13  Serious Business          2008  http://www.seriousbusiness.com
# 14           Huddler          2007          http://www.huddler.com
# 15           Genbook          2007          http://www.genbook.com
# 16              Lyft          2007                 http://lyft.com
# 17              Lyft          2007                 http://lyft.com
# 18             Roost          2007            http://www.roost.com
# 19            Gydget          2007           http://www.gydget.com
# 20      InnerRewards          2008     http://www.InnerRewards.com
# 21      InnerRewards          2008     http://www.InnerRewards.com
# 22         Transpera          2007        http://www.transpera.com
# 23           Lookery          2007          http://www.lookery.com
# 24        5th Finger          2008        http://www.5thFinger.com
# 25            Heyzap          2009           http://www.heyzap.com
# 26            ngmoco          2008           http://www.ngmoco.com
# 27            PicApp          2008           http://www.picapp.com
# 28         99designs          2008            http://99designs.com
# 29              KODA          2008                  http://koda.us
# 30           Dropbox          2007          http://www.dropbox.com
# 31       Clikthrough          2007          http://clikthrough.com
# 32             Zoosk          2007            http://www.zoosk.com
# 33         GoodGuide          2007            http://goodguide.com
# 34         GoodGuide          2007            http://goodguide.com
# 35           Coveroo          2008          http://www.coveroo.com
# 36            Minted          2007           http://www.minted.com
# 37             Zynga          2007            http://www.zynga.com
# 38         Kidlandia          2008   http://kidlandia.yolasite.com
# 39         Posterous          2008            http://posterous.com
# 40          Stitcher          2008         http://www.stitcher.com
# 41            GitHub          2008               http://github.com
# 42           Seesmic          2007              http://seesmic.com
# 43          Outspark          2007         http://www.outspark.com
# 44       doubleTwist          2007      http://www.doubletwist.com
# 45        GameLayers          2007           http://gamelayers.com
# 46       Open Places          2008              http://openplac.es
#
#    category_code                               description total_money_raised  \
# 0       software                 Private Academic Networks              $8.5M
# 1    games_video  Digital Entertainment and Media Platform              $4.8M
# 2         social         Mobile App for Meeting New People               $22M
# 3      ecommerce        Sell photos online on your website             $1.82M
# 4       hardware                     Avatar community site             $10.2M
# 5         mobile                                                       $11.5M
# 6            web        The Web's Community of Communities             $10.5M
# 7            web                                                       $3.18M
# 8            web                    Document collaboration              $1.3M
# 9            web                                                          $4M
# 10           web                                                          $4M
# 11           web                             Free Websites               $25M
# 12      software                 Social Marketing Platform             $11.3M
# 13   games_video            Social Game Development Studio                $4M
# 14           web                      We Know Communities.             $22.8M
# 15           web                                                        $2.2M
# 16      software                   Your friend with a car™             $82.5M
# 17      software                   Your friend with a car™             $82.5M
# 18      software                 Social Marketing Platform             $13.5M
# 19           web                    Marketing Widget Maker                $1M
# 20     ecommerce         Spa and Well-being social network                $1M
# 21     ecommerce         Spa and Well-being social network                $1M
# 22        mobile                  mobile video advertising             $19.5M
# 23           web                Social Network Advertising             $3.15M
# 24        mobile      Responsive Design Solutions Provider                $7M
# 25   games_video                 Social Discovery Platform             $7.97M
# 26   games_video                      Games for the iPhone             $44.8M
# 27           web                                                        $3.2M
# 28        design         Online graphic design marketplace               $35M
# 29           web     Social Recruiting and Job Search Site              $4.5M
# 30      software  Always have your stuff, wherever you are              $257M
# 31      software                        Interactive Videos                $2M
# 32        social                Behavioral Matchmaking(TM)             $61.6M
# 33           web                    Rating and review site             $14.2M
# 34           web                    Rating and review site             $14.2M
# 35      hardware                                                        $3.8M
# 36     ecommerce            marketplace for design and art             $52.7M
# 37   games_video            Network of gaming applications              $860M
# 38           web                                                       $3.23M
# 39           web                   Web Publishing Platform             $10.1M
# 40        mobile      It is a leading mobile audio company             $18.7M
# 41      software                             Social Coding              $100M
# 42           web              Social software applications               $16M
# 43   games_video                     Video game publishing             $23.3M
# 44      software          Music for the Internet of Things              $7.5M
# 45           web               Multiplayer Networked Games                $2M
# 46           web                                    Travel              $1.1M
#
#              city country_code        long        lat
# 0   San Francisco          USA -122.392142  37.782263
# 1   San Francisco          USA -122.393229  37.781265
# 2   San Francisco          USA -122.391249  37.780054
# 3   San Francisco          USA -122.394871  37.779501
# 4   San Francisco          USA -122.397582  37.785271
# 5   San Francsico          USA -122.396627  37.777072
# 6   San Francisco          USA -122.397672  37.786906
# 7   San Francisco          USA -122.400591  37.782163
# 8   San Francisco          USA -122.397141  37.788115
# 9   San Francisco          USA -122.399972  37.787092
# 10  San Francisco          USA -122.399972  37.787092
# 11  San Francisco          USA -122.395475  37.791115
# 12  San Francisco          USA -122.401333  37.788653
# 13  San Francisco          USA -122.401362  37.789321
# 14  San Francisco          USA -122.401362  37.789321
# 15  San Francisco          USA -122.400779  37.789902
# 16  San Francisco          USA -122.400785  37.789903
# 17  San Francisco          USA -122.400785  37.789903
# 18  San Francisco          USA -122.402028  37.789129
# 19  San Francisco          USA -122.398398  37.791733
# 20  San Francisco          USA -122.404403  37.786910
# 21  San Francisco          USA -122.404403  37.786910
# 22  San Francisco          USA -122.405081  37.785792
# 23  San Francisco          USA -122.403865  37.788266
# 24  San Francisco          USA -122.402199  37.790099
# 25  San Francisco          USA -122.404149  37.790554
# 26  San Francisco          USA -122.401581  37.770510
# 27  San Francisco          USA -122.403124  37.794020
# 28  San Francisco          USA -122.400598  37.795531
# 29  San Francisco          USA -122.409710  37.788796
# 30  San Francisco          USA -122.408499  37.790943
# 31  San Francisco          USA -122.402286  37.796578
# 32  San Francisco          USA -122.409915  37.772640
# 33  San Francisco          USA -122.400003  37.798318
# 34  San Francisco          USA -122.400003  37.798318
# 35  San Francisco          USA -122.407603  37.770067
# 36  San Francisco          USA -122.403175  37.797435
# 37  San Francisco          USA -122.404234  37.765158
# 38  SAN FRANCISCO          USA -122.404321  37.801794
# 39  San Francisco          USA -122.419204  37.775196
# 40  San Francisco          USA -122.419204  37.775196
# 41  San Francisco          USA -122.419204  37.775196
# 42  San Francisco          USA -122.419204  37.775196
# 43  San Francisco          USA -122.419204  37.775196
# 44  San Francisco          USA -122.419204  37.775196
# 45  San Francisco          USA -122.402468  37.803847
# 46  San Francisco          USA -122.398379  37.758352

# %%
sf_data.to_json("./Output/sf_data.json",orient="records", lines=True)

# %% [markdown]
# # 2. DataFrame con los aeropuertos de San Francisco.

# %%
airports = pd.read_csv("./input/airports.csv") 
airports
# Out:
#           1                               Goroka Airport        Goroka  \
# 0         2                               Madang Airport        Madang
# 1         3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2         4                               Nadzab Airport        Nadzab
# 3         5  Port Moresby Jacksons International Airport  Port Moresby
# 4         6                  Wewak International Airport         Wewak
# ...     ...                                          ...           ...
# 7692  14106                          Rogachyovo Air Base        Belaya
# 7693  14107                        Ulan-Ude East Airport      Ulan Ude
# 7694  14108                         Krechevitsy Air Base      Novgorod
# 7695  14109                  Desierto de Atacama Airport       Copiapo
# 7696  14110                           Melitopol Air Base     Melitopol
#
#       Papua New Guinea  GKA  AYGA  -6.081689834590001  145.391998291  5282  \
# 0     Papua New Guinea  MAG  AYMD           -5.207080     145.789001    20
# 1     Papua New Guinea  HGU  AYMH           -5.826790     144.296005  5388
# 2     Papua New Guinea  LAE  AYNZ           -6.569803     146.725977   239
# 3     Papua New Guinea  POM  AYPY           -9.443380     147.220001   146
# 4     Papua New Guinea  WWK  AYWK           -3.583830     143.669006    19
# ...                ...  ...   ...                 ...            ...   ...
# 7692            Russia   \N  ULDA           71.616699      52.478298   272
# 7693            Russia   \N  XIUW           51.849998     107.737999  1670
# 7694            Russia   \N  ULLK           58.625000      31.385000    85
# 7695             Chile  CPO  SCAT          -27.261200     -70.779198   670
# 7696           Ukraine   \N  UKDM           46.880001      35.305000     0
#
#       10   U  Pacific/Port_Moresby  airport  OurAirports
# 0     10   U  Pacific/Port_Moresby  airport  OurAirports
# 1     10   U  Pacific/Port_Moresby  airport  OurAirports
# 2     10   U  Pacific/Port_Moresby  airport  OurAirports
# 3     10   U  Pacific/Port_Moresby  airport  OurAirports
# 4     10   U  Pacific/Port_Moresby  airport  OurAirports
# ...   ..  ..                   ...      ...          ...
# 7692  \N  \N                    \N  airport  OurAirports
# 7693  \N  \N                    \N  airport  OurAirports
# 7694  \N  \N                    \N  airport  OurAirports
# 7695  \N  \N                    \N  airport  OurAirports
# 7696  \N  \N                    \N  airport  OurAirports
#
# [7697 rows x 14 columns]

# %%
airport_sf = airports.loc[airports['Goroka'] == "San Francisco"]

# %%
airport_sf = airport_sf.rename(columns={'-6.081689834590001':'lat','145.391998291':'long'})
airport_sf=airport_sf.rename(columns={'Goroka Airport':'Airport'})
airport_sf=airport_sf[['Airport','lat','long']]

# %%
airport_sf.to_json("./Output/airport_sf.json",orient="records", lines=True)

# %% [markdown]
# # 3. DataFrame con los Starbucks de San Francisco

# %%
starbucks = pd.read_csv("./Input/starbucks.csv")

# %%
starbucks = starbucks.loc[starbucks['City'] == "San Francisco"]
starbucks = starbucks.loc[starbucks['Brand'] == "Starbucks"]
starbucks
# Out:
#            Brand  Store Number                    Store Name Ownership Type  \
# 14695  Starbucks     5396-1025        Church & Market - S.F.  Company Owned
# 14696  Starbucks       611-409                120 4th Street  Company Owned
# 14697  Starbucks  79770-123324  Safeway - San Francisco #995       Licensed
# 14699  Starbucks  79532-102919        Safeway - Noriega #985       Licensed
# 14700  Starbucks   74816-73618  Safeway - San Francisco #667       Licensed
# ...          ...           ...                           ...            ...
# 14779  Starbucks    5836-13469                  3rd & Howard  Company Owned
# 14780  Starbucks       545-488                    24th & Noe  Company Owned
# 14781  Starbucks  14311-115765                  Owens & 16th  Company Owned
# 14782  Starbucks  10347-100168                Third & Market  Company Owned
# 14783  Starbucks   9211-249564                    One Market  Company Owned
#
#                           Street Address           City State/Province  \
# 14695                 2018 Market Street  San Francisco             CA
# 14696                     120 4th Street  San Francisco             CA
# 14697  1335 Webster, Stonestown Galleria  San Francisco             CA
# 14699                2350 Noriega Street  San Francisco             CA
# 14700          5290 Diamond Heights Blvd  San Francisco             CA
# ...                                  ...            ...            ...
# 14779                        201 3rd St.  San Francisco             CA
# 14780                   3995 24th Street  San Francisco             CA
# 14781  1700 Owens Street, Third & Market  San Francisco             CA
# 14782                     7 Third Street  San Francisco             CA
# 14783                1 Market Plaza, SP6  San Francisco             CA
#
#       Country   Postcode    Phone Number                       Timezone  \
# 14695      US  941141314  (415) 431-5561  GMT-08:00 America/Los_Angeles
# 14696      US  941033004  (415) 284-0579  GMT-08:00 America/Los_Angeles
# 14697      US  941154277    415-921-4557  GMT-08:00 America/Los_Angeles
# 14699      US  941224240             NaN  GMT-08:00 America/Los_Angeles
# 14700      US  941312118    415-824-7744  GMT-08:00 America/Los_Angeles
# ...       ...        ...             ...                            ...
# 14779      US  941033143  (415) 644-0072  GMT-08:00 America/Los_Angeles
# 14780      US  941143703  (415) 826-1118  GMT-08:00 America/Los_Angeles
# 14781      US  941580002    415-252-7423  GMT-08:00 America/Los_Angeles
# 14782      US  941033214      4159799530  GMT-08:00 America/Los_Angeles
# 14783      US      94111      4155436345  GMT-08:00 America/Los_Angeles
#
#        Longitude  Latitude
# 14695    -122.43     37.77
# 14696    -122.40     37.78
# 14697    -122.43     37.78
# 14699    -122.49     37.75
# 14700    -122.44     37.74
# ...          ...       ...
# 14779    -122.40     37.78
# 14780    -122.43     37.75
# 14781    -122.39     37.77
# 14782    -122.40     37.79
# 14783    -122.39     37.79
#
# [87 rows x 13 columns]

# %%
starbucks=starbucks[['Store Name','Longitude','Latitude']]
starbucks=starbucks.rename(columns={'Longitude':'long','Latitude':'lat'})

# %%
starbucks.to_json("./Output/starbucks.json",orient="records", lines=True)

# %% [markdown]
# # 4. DataFrame para conseguir ubicacion de los night clubs de San Francisco.

# %%
import requests
from dotenv import load_dotenv
import os

# %%
load_dotenv(dotenv_path='.env')
token = os.getenv('google_api', 'No value found')

# %%
#API Google
"""
def next_page_tk(json):
    df = {}
    df = json['next_page_token']
    return df

def api_google(lat, long, radio, tipo):
    if type(next_token) = str
    response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token))
    print(response.status_code)
    print(("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token)))
    goo_api = response.json()
    return goo_api 

def api_google(lat, long, radio, tipo,next_token=0):
    if type(next_token) = str
        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}%pagetoken={}".format(lat, long, radio, tipo, token, next_token))
        print(response.status_code)
    else:
        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token))
        print(response.status_code)
    goo_api = response.json()
    return goo_api   
"""
# Out:
# '\ndef next_page_tk(json):\n    df = {}\n    df = json[\'next_page_token\']\n    return df\n\ndef api_google(lat, long, radio, tipo):\n    if type(next_token) = str\n    response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token))\n    print(response.status_code)\n    print(("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token)))\n    goo_api = response.json()\n    return goo_api \n\ndef api_google(lat, long, radio, tipo,next_token=0):\n    if type(next_token) = str\n        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}%pagetoken={}".format(lat, long, radio, tipo, token, next_token))\n        print(response.status_code)\n    else:\n        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token))\n        print(response.status_code)\n    goo_api = response.json()\n    return goo_api   \n'

# %%
def api_google(lat, long, radio, tipo,next_token=0):
    if type(next_token) == str:
        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}&pagetoken={}".format(lat, long, radio, tipo, token, next_token))
        print(response.status_code)
        print(("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}&pagetoken={}".format(lat, long, radio, tipo, token, next_token)))
    else:
        response = requests.get("https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types={}&key={}".format(lat, long, radio, tipo, token))
        print(response.status_code)
    goo_api = response.json()
    return goo_api

# %%
def next_page_tk(json):
    df = json['next_page_token']
    return df

# %%
goo_api = api_google(sf_point[1],sf_point[0],'5000','night_club')
goo_api.keys()
# Out:
# 200
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])

# %%
next_token = next_page_tk(goo_api)

# %%
goo_api1 = api_google(sf_point[1],sf_point[0],'5000','night_club',next_token)
# Out:
# 200
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=37.782263,-122.392142&radius=5000&types=night_club&key=AIzaSyCNJpM1F_ZuO_7SygFxrOVhwQQczqkPAQM&pagetoken=CrQCIQEAAOSJa-Poo8vhsbHZuyQVvdHVaXS0CTDx56w2YSmmx-LqvkybUFf1Hx5WfpfgIUdJPEFNwgZbxC_D_YQor4HDvjTkHsnhB7dkDspj2RzUSa7IzqBg4wJsEkM4w_DO4wdNm42UI4E3c-12dqUvtBixfgZkZu5DQILyEvYe8KUGwVhuOU4ToWFxy4VvHKcY9Bc_EY-g3TpIFZCs22H30kocBx5PPonHLa7p6GQ5avyiWTJ2gTWvXlklUeOfjzqdD40dnxGKxuHdA8Eeqoa1w44ehuA0iej0GUPFfZe53iqfZsVPqNtyqDygqUMXxk37FdXildZdpmj1wc9csBgQHNfrNQGx5CDfw-iy3ZWVb09q4xdtclgsWNKOSY3yZJhZxZhaRmUzn65gQX0eHZenV9IBpYcSEDh8iUJgqltXq7O9pBanrl0aFPRvFZAihJylZZhXRrpVC940lgPB

# %%
goo_api1
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CtQDwQEAAJsQ-o0RRD-aFQuGBlfTN9Vi7Zdb2sAbLuaVrE-wybkSq7z-gbGqUgx-CISvt3DyHUlE_f591dvl4FMVYiCr2UMLdYqkf89bHJ4JhTKfDT09oWNojy1FeP7n8jcutO66t3cv1qCJLut1laGh_qd9CuyvjHdawqz7c69fCYCSdqd4G8fmawFaA-jYcsofViZpcC1pnv8fLVGV8U3UA7HlT22j8ybMT4amp87sIPekbz_VzPyEP3L6bjHlSFLA-QGXOLZ5UYavwZjO93d1u3-IpMV6PFRK5EqZufHQ57hpdt9vlFWrlkebPSYV_IFHpD8N4Wzp7jQxbFSbMhKwcNEW2lRFOlFgM5fxhR_qPxcaz64NN0Cy4zLJwNbUBc7-9PzekV8FwBmw7SKp-0nnhjwHzYyx45hqqcprE-HVmiSk2yw0a0jVROYRIA7BHAQBMggw480AZeWT3patuJZVfiSec1JcM_ObhYpCoDoJn8NPKSN8-Pv9k0oVeF3N4Xx1j8hWV16XpOB94kd58Dr1EWN6kC99zEhHSe3pVvIITKyfQRLI-KZ1ijizKB9DYV_fBRJg8JCpIkDdSlmyEPkoGvu_8ZRyHiWjL5vlxUv1ZUjnIVthEhAHP3rrC8xbNZmwvt7NYjIsGhSroUeKR9Yr6aqa0UaWBfKQcUTqUA',
#  'results': [{'geometry': {'location': {'lat': 37.7753374, 'lng': -122.409891},
#     'viewport': {'northeast': {'lat': 37.7766413302915,
#       'lng': -122.4084851197085},
#      'southwest': {'lat': 37.7739433697085, 'lng': -122.4111830802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'de1ce1f03fa67d2f517aad977fb2f21ae7c62867',
#    'name': 'Cat Club',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107202384868730016646/photos">Mark Edgar Rivera</a>'],
#      'photo_reference': 'CmRaAAAAxBLwo7ze-wqOGBTiVR7zBetWuL-DMaHFinaQ6czG2FCYSBGkhsUZoRlZtowpjsOv6OqM7i1TUAjaRrfvISiXK8sWEQSUm5BtLJPvCu_vg60LEzjAwTPxBVSV006uzZqyEhB_AiHvfKKJy3dNyDRWLrK2GhS0SRJxTNFH7Y9HtWJ6r54nwyfSjA',
#      'width': 4032}],
#    'place_id': 'ChIJV3ADfoKAhYARI4XLvSsnkoo',
#    'plus_code': {'compound_code': 'QHGR+42 SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHGR+42'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJV3ADfoKAhYARI4XLvSsnkoo',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 472,
#    'vicinity': '1190 Folsom Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7845811, 'lng': -122.4331984},
#     'viewport': {'northeast': {'lat': 37.7859430302915,
#       'lng': -122.4317460197085},
#      'southwest': {'lat': 37.7832450697085, 'lng': -122.4344439802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '777718bef620e6bb12a15a25fba3e95b556e8de8',
#    'name': 'Boom Boom Room',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 773,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109060955713767212620/photos">Boom Boom Room</a>'],
#      'photo_reference': 'CmRaAAAAvr0p48ZCK8qaUOcImRu5zv5XWODmWNvKRB4jKlyZdJSgNZwopQXKH1EDBnE09l1EP0H9EfHeN8SabowPj6BRdEY4b3QkrTqFdDXRSWBFXP3HYNwQfYLp2Ckfn0l5RCvaEhC7GAxJMPQQMxM1KiO9E-4OGhQf02Oc01TbpoW7lkw-qzhO0ak6jA',
#      'width': 1160}],
#    'place_id': 'ChIJB4gZTbiAhYAR3rdrtW61BYs',
#    'plus_code': {'compound_code': 'QHM8+RP Western Addition, San Francisco, CA, United States',
#     'global_code': '849VQHM8+RP'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJB4gZTbiAhYAR3rdrtW61BYs',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 423,
#    'vicinity': '1601 Fillmore Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.78339, 'lng': -122.412179},
#     'viewport': {'northeast': {'lat': 37.7847177802915,
#       'lng': -122.4109883697085},
#      'southwest': {'lat': 37.7820198197085, 'lng': -122.4136863302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'a636b4b54eec2a5c3e645fbeb04c3e489a25bee1',
#    'name': 'Power Exchange',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2269,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104527439006210104568/photos">Power Exchange</a>'],
#      'photo_reference': 'CmRaAAAAZ-OLSxoog74c_m290OZXMwJopG9FY3bcv7No50hKKzNpxKk_LNLQb31NIl3E-bL0kRHMY81iRdHnP7EemHhd2VHN_c5yWBHBkm3eyM4P0LJztv5sElbqGF4MF7xWEaWaEhA6K39S_FtADPLQCwZ8jNkFGhS1ZI88CM63dby8y33k07wmTfUoig',
#      'width': 4032}],
#    'place_id': 'ChIJ0ZB3UYWAhYAR86uAn-j7P3M',
#    'plus_code': {'compound_code': 'QHMQ+94 Tenderloin, San Francisco, CA, United States',
#     'global_code': '849VQHMQ+94'},
#    'rating': 3.7,
#    'reference': 'ChIJ0ZB3UYWAhYAR86uAn-j7P3M',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 106,
#    'vicinity': '220 Jones Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.797494, 'lng': -122.406454},
#     'viewport': {'northeast': {'lat': 37.7989017302915,
#       'lng': -122.4050386197085},
#      'southwest': {'lat': 37.7962037697085, 'lng': -122.4077365802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'b7ab672fcc3e8ae578630a5b387d747d5c98614c',
#    'name': 'Vesuvio Cafe',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100689721516420319655/photos">Vesuvio Cafe</a>'],
#      'photo_reference': 'CmRaAAAAV8acuRpkVfPIjD9vJtAiFdqa0UG_KiyguUI7PWv12BPv1e80Dls7CjqLcRqbZNJ1G-EbYqo9Tuu3cMmcGDNPeETdJc3g_u2NoIuQfo3ZkEiFN07nZtY0rFBnLaRtxE51EhADwOv2UhppzHRxXi048CAfGhRmrBRQpYMaE9Jgts_4sSujzebkqw',
#      'width': 2048}],
#    'place_id': 'ChIJT2cmiPSAhYARwyhb3VgcriM',
#    'plus_code': {'compound_code': 'QHWV+XC Financial District, San Francisco, CA, United States',
#     'global_code': '849VQHWV+XC'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJT2cmiPSAhYARwyhb3VgcriM',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1002,
#    'vicinity': '255 Columbus Avenue, San Francisco'},
#   {'geometry': {'location': {'lat': 37.765222, 'lng': -122.399911},
#     'viewport': {'northeast': {'lat': 37.7664398802915,
#       'lng': -122.3985510197085},
#      'southwest': {'lat': 37.76374191970851, 'lng': -122.4012489802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '4d14276b3514f2974a6cd382f3b6edb0fc93b2f2',
#    'name': 'Thee Parkside',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116750797999944764767/photos">Jessica Pfund</a>'],
#      'photo_reference': 'CmRaAAAAmCbK4kC2WuhCYbkTFgsLV6Y_9Yzq7eFVONp9K-TkPofFYhLo2SszjilkmxGFz2p6SrdGlOD9LofVn0ILixROoW-o-MHR85fD6htH2P1whLcAoUPxXm7phtJg7A2nRhNmEhD3eB87vxuwO05tRPAxvGEpGhR4UQuQotrPhBHEHFovsfKqbjSXIw',
#      'width': 4032}],
#    'place_id': 'ChIJ8SXJ6sx_j4ARHRrwH9Z3R5k',
#    'plus_code': {'compound_code': 'QJ82+32 Potrero Hill, San Francisco, CA, United States',
#     'global_code': '849VQJ82+32'},
#    'price_level': 1,
#    'rating': 4.4,
#    'reference': 'ChIJ8SXJ6sx_j4ARHRrwH9Z3R5k',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 454,
#    'vicinity': '1600 17th Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7750572, 'lng': -122.4128419},
#     'viewport': {'northeast': {'lat': 37.7764437302915,
#       'lng': -122.4116312697085},
#      'southwest': {'lat': 37.7737457697085, 'lng': -122.4143292302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '044f0f726f77bec1c8c2e58c014004e0eb43d2a9',
#    'name': 'AsiaSF',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100137689115968868622/photos">Sean Burke</a>'],
#      'photo_reference': 'CmRaAAAARULhBj3K7uhUBj8O86ZcGF5SdVwFRP9T_5x4Vl8YPOVvi1-xbHCl0AMN0ssdzWiwvvH5rsOZ9ls3jQjb6suCVUnzbyYKJ22TlMr9DMk3HgMaT5QG92iq6mgXwga69PuKEhDvO8mz8JTNUbrljBSEQvjlGhT-r3yIOONYt4vnbSWOx4EiTAkosg',
#      'width': 4160}],
#    'place_id': 'ChIJfyKBTJ2AhYARFIK70ucK-mg',
#    'plus_code': {'compound_code': 'QHGP+2V SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHGP+2V'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJfyKBTJ2AhYARFIK70ucK-mg',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 444,
#    'vicinity': '201 9th Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7742363, 'lng': -122.4374101},
#     'viewport': {'northeast': {'lat': 37.77554408029149,
#       'lng': -122.4361592197085},
#      'southwest': {'lat': 37.7728461197085, 'lng': -122.4388571802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': '48caf3ef3e42eba145f2f00bd68dfb8f1a2178d5',
#    'name': 'Madrone Art Bar',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104534194219809102252/photos">Madrone Art Bar</a>'],
#      'photo_reference': 'CmRaAAAAYtRKVLzn3vq_I0649z7fmbJbEVaAAhFcFtJdyWa-xg_gvhqAmp1Wn9N4Fbhd-w9kElN7TRFe-fttBftDjRiVp3YZvLg2vc14lE-Lu9A9RneXbf6NOfnvGBrPnvxaWjuPEhAYi51AHUIY4_Yqc41L5eyDGhQIpYo1xXbU0yErks6v_6EwMmlULg',
#      'width': 6000}],
#    'place_id': 'ChIJpVZ7r6-AhYARKukA_jhcpxs',
#    'plus_code': {'compound_code': 'QHF7+M2 Western Addition, San Francisco, CA, United States',
#     'global_code': '849VQHF7+M2'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJpVZ7r6-AhYARKukA_jhcpxs',
#    'scope': 'GOOGLE',
#    'types': ['bar', 'night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 557,
#    'vicinity': '500 Divisadero Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7712539, 'lng': -122.4238647},
#     'viewport': {'northeast': {'lat': 37.7725932802915,
#       'lng': -122.4225793197085},
#      'southwest': {'lat': 37.7698953197085, 'lng': -122.4252772802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'b7d85faff74f91270c4c2ebbc45e772d9245c885',
#    'name': 'Pisco Latin Lounge',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111090645276023943007/photos">Pisco Latin Lounge</a>'],
#      'photo_reference': 'CmRaAAAAp5Ugxjp7cQdbdsQxoTxZLaOuIzemv6A4KgFG2Jjn-h_wKRtwC-IQg5zuZ5rg4FqnSnVRv2a5xOJX1-NXtagsdDGLSQPIL17PCGt-ovHkGneeDa-hJcUXfFAs4G52G4mbEhAeRrrBkc2116DEndiEVJW2GhTIujFAA5D5qYEtkuFIQ19b4ffhXA',
#      'width': 2048}],
#    'place_id': 'ChIJqX7P-Z-AhYAR3Uu-TKs9GSI',
#    'plus_code': {'compound_code': 'QHCG+GF Mission District, San Francisco, CA, United States',
#     'global_code': '849VQHCG+GF'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJqX7P-Z-AhYAR3Uu-TKs9GSI',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 33,
#    'vicinity': '1817 Market Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7809871, 'lng': -122.4084623},
#     'viewport': {'northeast': {'lat': 37.78237923029149,
#       'lng': -122.4071862697085},
#      'southwest': {'lat': 37.7796812697085, 'lng': -122.4098842302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': '3b3b1a25037fe8a2aa47a8178b0324480e69628e',
#    'name': 'Monarch',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 635,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100493487900144883410/photos">Monarch</a>'],
#      'photo_reference': 'CmRaAAAAcPsTm52NBWpefkPwDEfz142HV3phCiGEc8grZZQS1sfklbSZQFAw5yzGElUHCIImo0UAOXULc0BtbfOMV3SzM7jLxp_MD3SFukLSyQ17r0t4CBAdLDwZz7C2fiBjVMNZEhA4Wc8XLTytMewuTqm4DKC6GhRJh5HnLB1JBR0KZsp7WSdB0pvn7Q',
#      'width': 955}],
#    'place_id': 'ChIJ328vE4SAhYARpJpsQ3UcwHQ',
#    'plus_code': {'compound_code': 'QHJR+9J SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHJR+9J'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJ328vE4SAhYARpJpsQ3UcwHQ',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 391,
#    'vicinity': '101 6th Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7783101, 'lng': -122.392598},
#     'viewport': {'northeast': {'lat': 37.77950313029149,
#       'lng': -122.3910377197085},
#      'southwest': {'lat': 37.7768051697085, 'lng': -122.3937356802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '3bd4602e10cb06da13a94109f18aabe934c5d652',
#    'name': 'Lucky Strike',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 328,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118156644528333429914/photos">Lucky Strike</a>'],
#      'photo_reference': 'CmRaAAAAqO5s7mK-iinWDyf7_FabBAcorCLTlAqhCxh3GfaenF-b1fJHFK6auyK3YS69vPsZZ8u5aH8ifjwdeQKmCY2KKENYmIGbm35im_B314gv7p9cVkcV61FLZog97uxLgsSnEhDfjilorNGtigpVreOSOvDzGhTFVbNdQDU76j7Br8VvL7IXKcvL2g',
#      'width': 930}],
#    'place_id': 'ChIJ89UQqNd_j4ARKoqcRIR-dhs',
#    'plus_code': {'compound_code': 'QJH4+8X SoMa, San Francisco, CA, United States',
#     'global_code': '849VQJH4+8X'},
#    'price_level': 3,
#    'rating': 4.1,
#    'reference': 'ChIJ89UQqNd_j4ARKoqcRIR-dhs',
#    'scope': 'GOOGLE',
#    'types': ['bowling_alley',
#     'night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 733,
#    'vicinity': '200 King Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.78313869999999, 'lng': -122.4179586},
#     'viewport': {'northeast': {'lat': 37.78454818029149,
#       'lng': -122.4166230697085},
#      'southwest': {'lat': 37.7818502197085, 'lng': -122.4193210302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '794a53f21009d6288da9578abc21014255db30de',
#    'name': 'Chambers',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115787864719453844355/photos">Chambers eat + drink</a>'],
#      'photo_reference': 'CmRaAAAA8U0woN04hXJEubMzboYM7EevgmhydXgbulRnrMM8QkisgU6EB6tPYthXmC62-x6lPmjZZIdcwIJMVIRzS97QX56qlKTooguGP0Oc1siqASGrDRyzwfevtPiqeg3KU8AMEhBf3DoGa9VwvSsBBIumyhYmGhRBdDG9th6YU5tWZZNN3W-QerSuog',
#      'width': 5184}],
#    'place_id': 'ChIJ70zQuZCAhYARBOYFsIfxD6U',
#    'plus_code': {'compound_code': 'QHMJ+7R Tenderloin, San Francisco, CA, United States',
#     'global_code': '849VQHMJ+7R'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJ70zQuZCAhYARBOYFsIfxD6U',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 320,
#    'vicinity': '601 Eddy Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7885694, 'lng': -122.3981969},
#     'viewport': {'northeast': {'lat': 37.78988748029149,
#       'lng': -122.3968009197085},
#      'southwest': {'lat': 37.7871895197085, 'lng': -122.3994988802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'd666f7f1fa3af01c56f0265c7cee49d67e3298e9',
#    'name': 'Harlot',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101194371142924116371/photos">Houdini</a>'],
#      'photo_reference': 'CmRaAAAAH1WBrTJyinPksfkZ2PDGFy4Rl5ol6RmV7ASqOIgoe0F6pRpXZNbi82G-3QBE1OrTAJEGixsfYhFxUqfS8m6drZPJMLlIC3ELAPMltPY_0ed4XzT2nYTHHLBntxGXFPuhEhDRlG4RRzzTi_PRFuc9a5MFGhSpexzc_CxbzUbC9E4JZMqnt-8zgg',
#      'width': 4032}],
#    'place_id': 'ChIJ_wvnLmOAhYARfjey1qtQmg4',
#    'plus_code': {'compound_code': 'QJQ2+CP SoMa, San Francisco, CA, United States',
#     'global_code': '849VQJQ2+CP'},
#    'price_level': 3,
#    'rating': 3.8,
#    'reference': 'ChIJ_wvnLmOAhYARfjey1qtQmg4',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 95,
#    'vicinity': '46 Minna Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.783654, 'lng': -122.398461},
#     'viewport': {'northeast': {'lat': 37.7849378802915,
#       'lng': -122.3971950197085},
#      'southwest': {'lat': 37.7822399197085, 'lng': -122.3998929802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '0ae9fef063b529fdeac579d9ee48df1cb493705d',
#    'name': 'Osha Thai Restaurant and Lounge',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 667,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112658981745384727363/photos">Osha Thai Restaurant and Lounge</a>'],
#      'photo_reference': 'CmRaAAAAEIM4DOtGOBNgIw1sShlotiFsqo07_OFJ_6fJA_n3UXqrpSFZee4SUgbWL2BxWId7Jkh6XauTcXHuO2AHzbXdPps-UrkqzdI1-Om-Lq4rW52yDZpeD75bs1khKLvgeM4JEhCRrdFtRXAYoAsIVD4_j4UIGhRoHNaBrOo4eaZOZBwEWPGDq_hKJQ',
#      'width': 1000}],
#    'place_id': 'ChIJVRnYLHyAhYARhl2ZVJFi5iU',
#    'plus_code': {'compound_code': 'QJM2+FJ SoMa, San Francisco, CA, United States',
#     'global_code': '849VQJM2+FJ'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJVRnYLHyAhYARhl2ZVJFi5iU',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'meal_delivery',
#     'meal_takeaway',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 686,
#    'vicinity': '311 3rd Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7852269, 'lng': -122.4044815},
#     'viewport': {'northeast': {'lat': 37.7864508802915,
#       'lng': -122.4033168697085},
#      'southwest': {'lat': 37.7837529197085, 'lng': -122.4060148302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': 'f3ca11aff070c9f8f8288dcb4dc0b082cd80de74',
#    'name': 'The View Lounge',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 423,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103205555965956633128/photos">The View Lounge</a>'],
#      'photo_reference': 'CmRaAAAA_TurBUol9-pCcL8mZ9C98T2i5SaIIjfemPMQdYJJiQV34Iu1nmx2-qtaV77m4AS2yffWPva91gx1gtoC_vbSG2_5rwnkpzftacqcPpZ5fVl0UHx3L_9V0sC3W2cnCLOCEhAJFNxxemFDOo6RGZSzK6-qGhTw0dpPAx5gLw_RYcf_Tn7DAGX_KQ',
#      'width': 610}],
#    'place_id': 'ChIJZZ_cOYaAhYARnyfbDrAkvJ8',
#    'plus_code': {'compound_code': 'QHPW+36 SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHPW+36'},
#    'price_level': 3,
#    'rating': 4.4,
#    'reference': 'ChIJZZ_cOYaAhYARnyfbDrAkvJ8',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1675,
#    'vicinity': '780 Mission Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.79802929999999, 'lng': -122.4044496},
#     'viewport': {'northeast': {'lat': 37.79944278029149,
#       'lng': -122.4031137697085},
#      'southwest': {'lat': 37.79674481970849, 'lng': -122.4058117302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'c698cfde9cda4370e6cd6e70b5add20f73bf4006',
#    'name': 'Broadway Studios Venue',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3036,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110193225511387980259/photos">1UP Nation</a>'],
#      'photo_reference': 'CmRaAAAAqlaGHstiB2-6uKBY2RAXH63uf5CfDSySwPMB42y4eolOi6TJ0JMxsLOgBTvYMrKsXQsuE0LKqfTbSUfDJM_5IG602YtuYZKTYgVb0LdbF3pJgOB3W0ByDvTVS8E9Y_yKEhClKL1sg09ZPduyqNJraqOXGhSk_-25mQNGTqixFJi5D4Nfsfllig',
#      'width': 4048}],
#    'place_id': 'ChIJPWyk-PSAhYARibuHfm_7FVc',
#    'plus_code': {'compound_code': 'QHXW+66 Financial District, San Francisco, CA, United States',
#     'global_code': '849VQHXW+66'},
#    'rating': 4.5,
#    'reference': 'ChIJPWyk-PSAhYARibuHfm_7FVc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 62,
#    'vicinity': '435 Broadway, San Francisco'},
#   {'geometry': {'location': {'lat': 37.787588, 'lng': -122.4031888},
#     'viewport': {'northeast': {'lat': 37.7890064802915,
#       'lng': -122.4019302697085},
#      'southwest': {'lat': 37.7863085197085, 'lng': -122.4046282302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': '9916d48daa40cf01c32c66710a19bf86f4af0d53',
#    'name': 'Local Edition',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1368,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103112386721338348896/photos">Julio Sene</a>'],
#      'photo_reference': 'CmRaAAAAAwX5eszHdqAL8k01mEk0irIEQCrFC5BpzB42jMd0DGsns65NMOuekq8398l6hcmPmw5XWx5CBp-1hbyxOtKYbpeG_h9-ojTUSIJc2YYacDkvEqekP-JMFy6i_pSK8fJXEhABvtkWfBXlZfvct6qDtXqRGhT7qdnWr6raczpF5IxJ-qbgJ8Igzw',
#      'width': 2048}],
#    'place_id': 'ChIJezfMa4iAhYARh5hM01QRydg',
#    'plus_code': {'compound_code': 'QHQW+2P SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHQW+2P'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJezfMa4iAhYARh5hM01QRydg',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1790,
#    'vicinity': '691 Market Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.786797, 'lng': -122.394217},
#     'viewport': {'northeast': {'lat': 37.7882203802915,
#       'lng': -122.3927743697085},
#      'southwest': {'lat': 37.7855224197085, 'lng': -122.3954723302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '1cd36ca95e7a5cfddad198400ec5468079d2a373',
#    'name': 'Local Kitchen & Wine Merchant',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114632379179764630514/photos">Mee Cha</a>'],
#      'photo_reference': 'CmRaAAAAi7IQggtfgoVNiDw8RfTKKSoJDkt8Hbhk35Qcqc2nosHlAqE2XkX5pCYM2EEb0AsXPm8OF8IDikMxkstCwPowRGJIJ9G3KZoatRMZix7qtDQorNL9BF_eOAHEcv7vKHwHEhB5_KJG61l3bjt4_WJRrVrPGhSY2RSFcJzw9m5G4dJILrtb6VRI7A',
#      'width': 4032}],
#    'place_id': 'ChIJzWMEoXuAhYARnGNx8NeVTpY',
#    'plus_code': {'compound_code': 'QJP4+P8 SoMa, San Francisco, CA, United States',
#     'global_code': '849VQJP4+P8'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJzWMEoXuAhYARnGNx8NeVTpY',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'bar',
#     'liquor_store',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 300,
#    'vicinity': '330 1st Street #1, San Francisco'},
#   {'geometry': {'location': {'lat': 37.777312, 'lng': -122.403745},
#     'viewport': {'northeast': {'lat': 37.77862668029149,
#       'lng': -122.4025264697085},
#      'southwest': {'lat': 37.77592871970849, 'lng': -122.4052244302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': '80c94a595326ede60dbe7eb2d083f11b38fb5709',
#    'name': 'The EndUp',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108051781004381876913/photos">The EndUp</a>'],
#      'photo_reference': 'CmRaAAAAHBd5XfX9ozOwSTMfiMkcY9tpnk4NAZZYpB077SiZ5z7d1BQBD_nZxgjSuhl4LlAFhqi2K77b_6TDF9NLAdBVhd8-9bJYwkQfGcyUEbxR-VdNtLGniCMzB8yEHMjfzIQlEhDxjbloMtD4NVlON0iAih8bGhSE3gqxe8LhMvpf1rhsxmMSupJ6Ug',
#      'width': 2048}],
#    'place_id': 'ChIJOwXkLoCAhYAR4wOAUKL9gUI',
#    'plus_code': {'compound_code': 'QHGW+WG SoMa, San Francisco, CA, United States',
#     'global_code': '849VQHGW+WG'},
#    'price_level': 2,
#    'rating': 3.4,
#    'reference': 'ChIJOwXkLoCAhYAR4wOAUKL9gUI',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 195,
#    'vicinity': '401 6th Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.7688759, 'lng': -122.4194268},
#     'viewport': {'northeast': {'lat': 37.77033653029149,
#       'lng': -122.4180868197085},
#      'southwest': {'lat': 37.7676385697085, 'lng': -122.4207847802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': '44ed17dd20ee52dbb08ab2e75be2904ba5a80da7',
#    'name': 'Public Works',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 631,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111742945623632633965/photos">Public Works</a>'],
#      'photo_reference': 'CmRaAAAAbXvYU4G3Vq1FbZHU1Ml32VgiFP6pvb_gNYEtiaO-_ZJz2uGSmX2TxyIuxlOYAZ2FlGdR60sEsMByNkZXx0iJkl8C2UlAv-77xlNUg1xsUBFqgsyl9vefMdjWvu4KZGKcEhB8Axtm45XJZ0jIytyDNyX_GhT5ZgD8voSMn4njIQkOOj1uQjGQqQ',
#      'width': 948}],
#    'place_id': 'ChIJa4c8OyF-j4AR4kopWZOJZPM',
#    'plus_code': {'compound_code': 'QH9J+H6 Mission District, San Francisco, CA, United States',
#     'global_code': '849VQH9J+H6'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJa4c8OyF-j4AR4kopWZOJZPM',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 234,
#    'vicinity': '161 Erie Street, San Francisco'},
#   {'geometry': {'location': {'lat': 37.76068250000001, 'lng': -122.4354977},
#     'viewport': {'northeast': {'lat': 37.76212423029151,
#       'lng': -122.4341630697085},
#      'southwest': {'lat': 37.75942626970851, 'lng': -122.4368610302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bar-71.png',
#    'id': 'cbabce14723330e1a2ee3dd7a1ff6924091ea818',
#    'name': 'San Francisco Badlands',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115472401427558808265/photos">Thomas Hill</a>'],
#      'photo_reference': 'CmRaAAAAPj_pga8k4MQVqP_q86DwkIkYQ-yVk5MDiLdLXmrnj2QmGnln6ElrO_OlGB35yfENNyJ-T8sja0xsfIr1gZLUVCb3vy3cgYt_MsZ1ByXIDe-GKhKyysGg_n1vm7bM6DKvEhDNfJ-dhHyHKm5I5wvKkkydGhR1pv8JW42dmkAycgCZr6d3XjcrXQ',
#      'width': 3120}],
#    'place_id': 'ChIJsXfvzAR-j4ARRcUMHaCDjgg',
#    'plus_code': {'compound_code': 'QH67+7R The Castro, San Francisco, CA, United States',
#     'global_code': '849VQH67+7R'},
#    'price_level': 1,
#    'rating': 4.1,
#    'reference': 'ChIJsXfvzAR-j4ARRcUMHaCDjgg',
#    'scope': 'GOOGLE',
#    'types': ['night_club', 'bar', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 503,
#    'vicinity': '4121 18th Street, San Francisco'}],
#  'status': 'OK'}

# %%
def json_to_df(goo_df, json):
    for i in range(len(json['results'])):
        df={}
        df['cordenadas'] = json['results'][i]['geometry']['location']
        df['name'] = json['results'][i]['name']
        df['type'] = json['results'][i]['types'][0]
        df = pd.DataFrame(df)
        goo_df = goo_df.append(df)       
    return goo_df

# %%
goo_df = pd.DataFrame()
goo_df1 = pd.DataFrame()
goo_df = json_to_df(goo_df,goo_api)
goo_df1 = json_to_df(goo_df1,goo_api1)

goo_df = goo_df.append(goo_df1)
goo_df
# Out:
#      cordenadas                       name        type
# lat   37.771459                     Slim's  night_club
# lng -122.413318                     Slim's  night_club
# lat   37.771094                 DNA Lounge  night_club
# lng -122.412650                 DNA Lounge  night_club
# lat   37.784955  Great American Music Hall  night_club
# ..          ...                        ...         ...
# lng -122.403745                  The EndUp  night_club
# lat   37.768876               Public Works  night_club
# lng -122.419427               Public Works  night_club
# lat   37.760683     San Francisco Badlands  night_club
# lng -122.435498     San Francisco Badlands  night_club
#
# [80 rows x 3 columns]

# %%
goo_df['lat'] = goo_df['cordenadas']
goo_df['long'] = goo_df['cordenadas']
goo_df.head()
# Out:
#      cordenadas                       name        type         lat        long
# lat   37.771459                     Slim's  night_club   37.771459   37.771459
# lng -122.413318                     Slim's  night_club -122.413318 -122.413318
# lat   37.771094                 DNA Lounge  night_club   37.771094   37.771094
# lng -122.412650                 DNA Lounge  night_club -122.412650 -122.412650
# lat   37.784955  Great American Music Hall  night_club   37.784955   37.784955

# %%
def coor_to_l(goo_df):
    for i in range(len(goo_df['cordenadas'])):
        if i%2 != 0:
            goo_df['lat'][i] = goo_df['cordenadas'][i-1]
        else:
            goo_df['long'][i] = goo_df['cordenadas'][i-1]
    return goo_df

# %%
goo_df = coor_to_l(goo_df)
goo_df
# Out:
# C:\Users\traba\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\traba\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      cordenadas                       name        type        lat        long
# lat   37.771459                     Slim's  night_club  37.771459 -122.435498
# lng -122.413318                     Slim's  night_club  37.771459 -122.413318
# lat   37.771094                 DNA Lounge  night_club  37.771094 -122.413318
# lng -122.412650                 DNA Lounge  night_club  37.771094 -122.412650
# lat   37.784955  Great American Music Hall  night_club  37.784955 -122.412650
# ..          ...                        ...         ...        ...         ...
# lng -122.403745                  The EndUp  night_club  37.777312 -122.403745
# lat   37.768876               Public Works  night_club  37.768876 -122.403745
# lng -122.419427               Public Works  night_club  37.768876 -122.419427
# lat   37.760683     San Francisco Badlands  night_club  37.760683 -122.419427
# lng -122.435498     San Francisco Badlands  night_club  37.760683 -122.435498
#
# [80 rows x 5 columns]

# %%
goo_df = goo_df.drop('lat')

# %%
goo_df = goo_df.reset_index()
goo_df=goo_df[['name','type','lat','long']]
goo_df = goo_df.rename(columns={'name':'pub_name'})

# %%
goo_df.head()
# Out:
#                     pub_name        type        lat        long
# 0                     Slim's  night_club  37.771459 -122.413318
# 1                 DNA Lounge  night_club  37.771094 -122.412650
# 2  Great American Music Hall  night_club  37.784955 -122.418871
# 3                  The Big 4  night_club  37.791545 -122.412300
# 4                    25 Lusk  night_club  37.778469 -122.394311

# %%
goo_df.to_json("./Output/goo_df.json",orient="records", lines=True)

# %% [markdown]
# # Selección final

# %% [markdown]
# Finalmente he unificado en tableau los 4 DataFrame consiguiendo asi un mapa dentro del rango.
#
# El lugar que he elegido es el: 835 Market St #700, San Francisco, CA 94103, EE. UU.
# Google Maps: "https://www.google.com/maps/place/Ellation+%7C+Crunchyroll/@37.7850079,-122.4072152,16.88z/data=!4m5!3m4!1s0x8085808608ca269d:0xe06022877d3fde60!8m2!3d37.7848236!4d-122.4068691"
#
# Este punto cumple con los criterios de:
#
# 1. Cerca de empresas de diseño y afines, donde los empleados puedan ir a charlas y relacionarse.
# 2. Cerca de tech startup que han levantado mas de 1 millon de dolares.
# 3. Cerca de una gran cantidad de Starbucks.
# 4. Cerca de un Aeropuerto.
# 5. Cerca de varias salas de fiesta y bares.
# 6. No estar cerca de ninguna empresa que tenga mas de 10 años.
#
# y la mia:
# 7. Estar cerca de la playa para darse buenos baños relajantes.
#
# Respecto al mapa:
# - Los puntos verdes son Starbucks.
# - El punto marron el aeropuerto.
# - Los puntos azules clubs nocturnos y bares.
# - Los puntos rojos empresas que cumplen los criterios.
# - El punto gris es la ubicacion elegida.
#
# No he podido meterlo en Tableau porque me fallaba al guardarlo, adjunto las fotos.
#
# Un proyecto muy entretenido, espero que os guste.
# Saludos!

# %% [markdown]
# <img src="./input/mapa_lejos.png">

# %% [markdown]
# <img src="./input/mapa_cerca.png">
